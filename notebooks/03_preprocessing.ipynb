# %% [markdown]
# ### Prétraitement des textes

# %% [markdown]
# ##### 1. Charger les données

# %%
import pandas as pd

data_train = pd.read_csv('../data/raw/train.csv')
data_test = pd.read_csv('../data/raw/test.csv')

# %% [markdown]
# ##### 2. Normaliser les textes: Mettre en minuscules

# %%
data_train['text_lowercase'] = data_train['text'].str.lower()
data_test['text_lowercase'] = data_test['text'].str.lower()
